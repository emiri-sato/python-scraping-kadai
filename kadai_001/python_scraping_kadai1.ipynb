# %%
# !pip install requests beautifulsoup4

# %%
import requests
from bs4 import BeautifulSoup

url='https://news.yahoo.co.jp/articles/d911fa12304f081eae107e949dc458b27e380d25'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
body_element=soup.find('p', class_='sc-54nboa-0 deLyrJ yjSlinkDirectlink highLightSearchTarget')
print(body_element.text)
# Out:
# 11月15日に結党70年を迎える自由民主党。1955年、「保守合同」により誕生した自民党は単独与党として政権を担い、日本社会党が最大野党という「55年体制」が長らく続いた。1993年に初めて野党に転落すると、その後は連立政権樹立、再びの下野、少数与党など厳しい状況に置かれてきた。今年10月の総裁選で初の女性総裁となる高市早苗氏が選出されると、26年ぶりに自民党議員だけで組閣という新しい時代に入った。自民党はどういう変遷を経て、今後はどうなっていくのか。有識者3人に話を聞いた。（文・写真：ジャーナリスト・小川匡則／Yahoo!ニュース オリジナル 特集編集部）
